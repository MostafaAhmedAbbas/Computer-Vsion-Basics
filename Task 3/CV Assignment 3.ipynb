# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
def Segment(image,n):
    img=Image.open(image)
   # img.show()
    newImg=img.copy()
    newImg.load()
    ImgArray=np.asarray(newImg)
    size = newImg.size
    x=size[0]
    y=size[1]
    xshape = ImgArray.shape[0]
    yshape= ImgArray.shape[1]
    Corners= ImgArray[0][0] + ImgArray[0][yshape-1] + ImgArray[xshape-1][0] + ImgArray[xshape-1][yshape-1]
    meanCorners= Corners // 4
    text=""
    sum=0
    for i in range(0,xshape-2):
        for j in range(0,yshape-2):
            sum= sum + ImgArray[i][j]
    sum= sum-Corners
    threshhold = (sum+ meanCorners)//2
    text += str(threshhold) +'\n'
    
    arrayAddition = np.zeros((xshape,yshape))
    
    for z in range(0,n+1):
        counter=0
        sum=0
        newArray= np.zeros((xshape,yshape))
        newArray2= np.zeros((xshape,yshape))
        for i in range(0,xshape-2):
            for j in range(0,yshape-2):
                if(ImgArray[i][j] < threshhold ):
                    counter += 1
                    sum += ImgArray[i][j] 
                    newArray[i][j] = ImgArray[i][j]
                if(ImgArray[i][j] > threshhold ):
                    newArray2[i][j] = ImgArray[i][j]
                    
      #  name = "GUC_3_" + str(z) + ".jpg"
        imgplot = plt.imshow(newArray, cmap='gray')
        fig=plt.gcf()
        plt.show()
        plt.draw()
        fig.savefig(name)
        arrayAddition = arrayAddition + newArray2
        #imgplot = plt.imshow(newArray, cmap='gray')
        plt.show()
        threshhold = sum /counter
        text += str(threshhold) +'\n'
        
    imgplot = plt.imshow(arrayAddition, cmap='gray')
   # plt.show()
    #fig=plt.gcf()
   # plt.show()
 #   plt.draw()
   # fig.savefig('GUC_3.jpg')
   # text_file =open("threshhold_4.txt","w")
   # text_file.write(text)
   # text_file.close()

# %%
Segment("GUC.jpg",3)
# Out:
# C:\Users\Mostafa\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: overflow encountered in ubyte_scalars
#   if sys.path[0] == '':

# %%
Segment("GUC.jpg",4)
# Out:
# C:\Users\Mostafa\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: overflow encountered in ubyte_scalars
#   if sys.path[0] == '':
